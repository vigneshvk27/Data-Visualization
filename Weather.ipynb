# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

dt = pd.read_csv('weather.csv')
print(dt.head())
# Out:
#          Date  Temperature  Apparent Temperature  Humidity
# 0  01-04-2006          9.0                  7.39      0.89
# 1  02-04-2006          9.0                  7.23      0.86
# 2  03-04-2006          9.0                  9.38      0.89
# 3  04-04-2006          8.0                  5.94      0.83
# 4  05-04-2006          9.0                  6.98      0.83

# %%
dt = dt.sample(frac=0.1)
plt.figure(figsize=(10, 6))
plt.plot(dt['Date'], dt['Temperature'])
plt.title('Temperature Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(dt['Temperature'], kde=True, bins=20)
plt.title('Temperature Histogram')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Temperature', y='Humidity', data=dt)
plt.title('Temperature and Humidity')
plt.xlabel('Temperature (°C)')
plt.ylabel('Humidity (%)')
plt.show()

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d %H:%M:%S.%f %z')
numeric_data = data[['Temperature', 'Apparent Temperature', 'Humidity']]
correlation_matrix = numeric_data.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True)
plt.title('Correlation Heatmap')
plt.show()
